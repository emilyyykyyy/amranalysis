# %% [markdown]
# # **Gene Sequences Data Setup**
#
# ### ***Objectives for this notebook***
# - Prepare gene sequence data for machine learning use
# - Count ratios of DNA bases (A, C, G, T)

# %% [markdown]
# ### Data Preparation
# *Note: Rename the sequence you wish to use as "sequence.fna"*

# %%
from Bio import SeqIO
import pandas as pd

fna_file = "sequence.fna"
record = next(SeqIO.parse(fna_file, "fasta"))
sequence = str(record.seq).upper()

df = pd.DataFrame({
    "position": range(1, len(sequence) + 1),  # 1-based indexing
    "base": list(sequence)
})

df.head()
# Out:
#    position base
# 0         1    A
# 1         2    C
# 2         3    T
# 3         4    A
# 4         5    C

# %% [markdown]
# ### Results

# %%
# Calculate the count of each base
base_counts = df['base'].value_counts()

# Calculate the ratio of each base
base_ratios = base_counts / len(df_bases)

# Show the counts and ratios
print("\nBase Counts:\n", base_counts)
print("\nBase Ratios:\n", base_ratios)
# Out:
# Base Counts:
#  base
# T    971532
# A    960377
# C    470674
# G    470186
# Name: count, dtype: int64
#
# Base Ratios:
#  base
# T    0.338187
# A    0.334304
# C    0.163840
# G    0.163670
# Name: count, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a figure with two subplots: one for the bar plot and one for the pie chart
fig, axs = plt.subplots(1, 2, figsize=(16, 6))

# Bar Plot of base counts
sns.barplot(x=base_counts.index, y=base_counts.values, palette="viridis", ax=axs[0])
axs[0].set_title("Base Counts in Sequence")
axs[0].set_xlabel("Base")
axs[0].set_ylabel("Count")

# Pie Chart of base ratios
axs[1].pie(base_ratios, labels=base_ratios.index, autopct="%1.1f%%", startangle=140, colors=sns.color_palette("Set2", n_colors=4))
axs[1].set_title("Base Composition of Sequence")

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\emily\AppData\Local\Temp\ipykernel_42748\3166826701.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=base_counts.index, y=base_counts.values, palette="viridis", ax=axs[0])
